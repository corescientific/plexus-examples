# %%
# !pip install mlflow hyperopt

# %%
from functools import partial
from hyperopt import Trials, fmin, tpe, hp, STATUS_OK
import tensorflow as tf
from tensorflow.keras import backend as K
import datetime

from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D


import mlflow
import mlflow.tensorflow
mlflow.tensorflow.autolog(every_n_iter=1)

# %%
tf.__version__
# Out:
# '1.15.4'

# %%
# You would have to expose this containers port also
#remote_server_uri = "mlruns" # set to your server URI
remote_server_uri = "file:/home/acc/mlflow"
mlflow.set_tracking_uri(remote_server_uri)
mlflow.set_experiment("my-hypteropt-experiment3")

# %%
def f1_score(y_true, y_pred):
    # returns batch-wise averge f1, not weighted
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))


def train(constants, hyperparams):

    #mlflow.start_run()
    with mlflow.start_run():
        params = {**constants, **hyperparams}

        batch_size = int(params['batch_size'])
        num_classes = int(params['num_classes'])
        epochs = int(params['epochs'])
        lr = float(params['lr'])
        optimizer_str = params['optimizer_str']

        # input image dimensions
        img_rows, img_cols = 28, 28
        input_shape = (img_rows, img_cols, 1)

        # the data, split between train and test sets
        (x_train, y_train), (x_test, y_test) = mnist.load_data()

        x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
        x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)

        x_train = x_train.astype('float32')
        x_test = x_test.astype('float32')
        x_train /= 255
        x_test /= 255

        # convert class vectors to binary class matrices
        y_train = tf.keras.utils.to_categorical(y_train, num_classes)
        y_test = tf.keras.utils.to_categorical(y_test, num_classes)

        callbacks = [tf.keras.callbacks.EarlyStopping(
            monitor="val_loss", patience=5  )]

        model = Sequential()
        model.add(Conv2D(32, kernel_size=(3, 3),
                         activation='relu',
                         input_shape=input_shape))
        model.add(Conv2D(64, (3, 3), activation='relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))
        model.add(Flatten())
        model.add(Dense(128, activation='relu'))
        model.add(Dropout(0.5))
        model.add(Dense(num_classes, activation='softmax'))

        model.compile(loss=tf.keras.losses.categorical_crossentropy,
                      optimizer=optimizer_str,
                      # user defined metrics that get reported
                      metrics=['accuracy', f1_score])

        history = model.fit(x_train, y_train,
                            batch_size=batch_size,
                            epochs=epochs,
                            verbose=2,
                            callbacks=callbacks,
                            validation_data=(x_test, y_test))

    #mlflow.end_run()
    return {'loss': min(history.history['val_f1_score']), 'status': STATUS_OK}


# Keep parallelism at or below number of hyperparams
search_space = {
    'lr': hp.uniform('lr', 1e-6, 1e-4),
    'optimizer_str': hp.choice('optimizer_str', ['RMSprop', 'Adam', 'Adadelta'])
}

constants = {
    'batch_size': 128,
    'epochs': 10,
    'num_classes': 10
}

#hyperopt

train_func = partial(train, constants)

# using default experiment
best = fmin(train_func, space=search_space,
            algo=tpe.suggest, max_evals=10, trials=Trials())
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 - 32s - loss: 0.2396 - acc: 0.9277 - f1_score: 0.9205 - val_loss: 0.0486 - val_acc: 0.9847 - val_f1_score: 0.9848
#
# Epoch 2/10
# 60000/60000 - 31s - loss: 0.0852 - acc: 0.9742 - f1_score: 0.9745 - val_loss: 0.0434 - val_acc: 0.9847 - val_f1_score: 0.9853
#
# Epoch 3/10
# 60000/60000 - 31s - loss: 0.0667 - acc: 0.9803 - f1_score: 0.9806 - val_loss: 0.0347 - val_acc: 0.9893 - val_f1_score: 0.9894
#
# Epoch 4/10
# 60000/60000 - 31s - loss: 0.0523 - acc: 0.9837 - f1_score: 0.9839 - val_loss: 0.0289 - val_acc: 0.9905 - val_f1_score: 0.9904
#
# Epoch 5/10
# 60000/60000 - 31s - loss: 0.0450 - acc: 0.9862 - f1_score: 0.9863 - val_loss: 0.0300 - val_acc: 0.9901 - val_f1_score: 0.9902
#
# Epoch 6/10
# 60000/60000 - 32s - loss: 0.0399 - acc: 0.9873 - f1_score: 0.9874 - val_loss: 0.0284 - val_acc: 0.9905 - val_f1_score: 0.9905
#
# Epoch 7/10
# 60000/60000 - 32s - loss: 0.0340 - acc: 0.9892 - f1_score: 0.9894 - val_loss: 0.0302 - val_acc: 0.9909 - val_f1_score: 0.9911
#
# Epoch 8/10
# 60000/60000 - 33s - loss: 0.0308 - acc: 0.9900 - f1_score: 0.9901 - val_loss: 0.0287 - val_acc: 0.9905 - val_f1_score: 0.9908
#
# Epoch 9/10
# 60000/60000 - 32s - loss: 0.0278 - acc: 0.9912 - f1_score: 0.9912 - val_loss: 0.0295 - val_acc: 0.9907 - val_f1_score: 0.9907
#
# Epoch 10/10
# 60000/60000 - 33s - loss: 0.0275 - acc: 0.9909 - f1_score: 0.9909 - val_loss: 0.0265 - val_acc: 0.9913 - val_f1_score: 0.9915
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 - 32s - loss: 2.2857 - acc: 0.1322 - f1_score: 0.0000e+00 - val_loss: 2.2423 - val_acc: 0.2389 - val_f1_score: 0.0000e+00
#
# Epoch 2/10
# 60000/60000 - 32s - loss: 2.2151 - acc: 0.2353 - f1_score: 0.0000e+00 - val_loss: 2.1565 - val_acc: 0.4182 - val_f1_score: 0.0000e+00
#
# Epoch 3/10
# 60000/60000 - 34s - loss: 2.1271 - acc: 0.3482 - f1_score: 0.0000e+00 - val_loss: 2.0465 - val_acc: 0.5716 - val_f1_score: 0.0000e+00
#
# Epoch 4/10
# 60000/60000 - 32s - loss: 2.0115 - acc: 0.4450 - f1_score: 0.0000e+00 - val_loss: 1.8984 - val_acc: 0.6728 - val_f1_score: 0.0000e+00
#
# Epoch 5/10
# 60000/60000 - 32s - loss: 1.8621 - acc: 0.5260 - f1_score: 0.0016 - val_loss: 1.7087 - val_acc: 0.7306 - val_f1_score: 1.9625e-04
#
# Epoch 6/10
# 60000/60000 - 34s - loss: 1.6855 - acc: 0.5827 - f1_score: 0.0286 - val_loss: 1.4918 - val_acc: 0.7669 - val_f1_score: 0.0452
#
# Epoch 7/10
# 60000/60000 - 33s - loss: 1.5039 - acc: 0.6193 - f1_score: 0.1193 - val_loss: 1.2778 - val_acc: 0.7961 - val_f1_score: 0.1801
#
# Epoch 8/10
# 60000/60000 - 33s - loss: 1.3326 - acc: 0.6528 - f1_score: 0.2664 - val_loss: 1.0916 - val_acc: 0.8155 - val_f1_score: 0.3911
#
# Epoch 9/10
# 60000/60000 - 33s - loss: 1.1913 - acc: 0.6784 - f1_score: 0.4074 - val_loss: 0.9417 - val_acc: 0.8282 - val_f1_score: 0.5583
#
# Epoch 10/10
# 60000/60000 - 32s - loss: 1.0803 - acc: 0.6980 - f1_score: 0.5137 - val_loss: 0.8267 - val_acc: 0.8395 - val_f1_score: 0.6639
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 - 32s - loss: 0.2366 - acc: 0.9287 - f1_score: 0.9225 - val_loss: 0.0498 - val_acc: 0.9825 - val_f1_score: 0.9823
#
# Epoch 2/10
# 60000/60000 - 32s - loss: 0.0835 - acc: 0.9768 - f1_score: 0.9769 - val_loss: 0.0441 - val_acc: 0.9855 - val_f1_score: 0.9860
#
# Epoch 3/10
# 60000/60000 - 32s - loss: 0.0637 - acc: 0.9816 - f1_score: 0.9816 - val_loss: 0.0469 - val_acc: 0.9842 - val_f1_score: 0.9842
#
# Epoch 4/10
# 60000/60000 - 32s - loss: 0.0544 - acc: 0.9846 - f1_score: 0.9846 - val_loss: 0.0333 - val_acc: 0.9893 - val_f1_score: 0.9889
#
# Epoch 5/10
# 60000/60000 - 32s - loss: 0.0514 - acc: 0.9852 - f1_score: 0.9853 - val_loss: 0.0330 - val_acc: 0.9895 - val_f1_score: 0.9889
#
# Epoch 6/10
# 60000/60000 - 32s - loss: 0.0496 - acc: 0.9854 - f1_score: 0.9856 - val_loss: 0.0358 - val_acc: 0.9894 - val_f1_score: 0.9896
#
# Epoch 7/10
# 60000/60000 - 33s - loss: 0.0477 - acc: 0.9863 - f1_score: 0.9865 - val_loss: 0.0329 - val_acc: 0.9895 - val_f1_score: 0.9889
#
# Epoch 8/10
# 60000/60000 - 33s - loss: 0.0515 - acc: 0.9859 - f1_score: 0.9859 - val_loss: 0.0380 - val_acc: 0.9889 - val_f1_score: 0.9891
#
# Epoch 9/10
# 60000/60000 - 33s - loss: 0.0499 - acc: 0.9862 - f1_score: 0.9860 - val_loss: 0.0444 - val_acc: 0.9875 - val_f1_score: 0.9868
#
# Epoch 10/10
# 60000/60000 - 32s - loss: 0.0532 - acc: 0.9855 - f1_score: 0.9854 - val_loss: 0.0417 - val_acc: 0.9891 - val_f1_score: 0.9894
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 - 32s - loss: 0.2223 - acc: 0.9332 - f1_score: 0.9277 - val_loss: 0.0557 - val_acc: 0.9825 - val_f1_score: 0.9820
#
# Epoch 2/10
# 60000/60000 - 32s - loss: 0.0809 - acc: 0.9765 - f1_score: 0.9764 - val_loss: 0.0383 - val_acc: 0.9878 - val_f1_score: 0.9880
#
# Epoch 3/10
# 60000/60000 - 32s - loss: 0.0597 - acc: 0.9824 - f1_score: 0.9826 - val_loss: 0.0323 - val_acc: 0.9892 - val_f1_score: 0.9891
#
# Epoch 4/10
# 60000/60000 - 32s - loss: 0.0518 - acc: 0.9845 - f1_score: 0.9847 - val_loss: 0.0343 - val_acc: 0.9889 - val_f1_score: 0.9887
#
# Epoch 5/10
# 60000/60000 - 32s - loss: 0.0479 - acc: 0.9857 - f1_score: 0.9858 - val_loss: 0.0304 - val_acc: 0.9899 - val_f1_score: 0.9900
#
# Epoch 6/10
# 60000/60000 - 32s - loss: 0.0447 - acc: 0.9866 - f1_score: 0.9865 - val_loss: 0.0290 - val_acc: 0.9913 - val_f1_score: 0.9911
#
# Epoch 7/10
# 60000/60000 - 32s - loss: 0.0429 - acc: 0.9871 - f1_score: 0.9872 - val_loss: 0.0316 - val_acc: 0.9896 - val_f1_score: 0.9900
#
# Epoch 8/10
# 60000/60000 - 32s - loss: 0.0446 - acc: 0.9866 - f1_score: 0.9868 - val_loss: 0.0386 - val_acc: 0.9878 - val_f1_score: 0.9881
#
# Epoch 9/10
# 60000/60000 - 32s - loss: 0.0449 - acc: 0.9877 - f1_score: 0.9875 - val_loss: 0.0305 - val_acc: 0.9903 - val_f1_score: 0.9907
#
# Epoch 10/10
# 60000/60000 - 32s - loss: 0.0436 - acc: 0.9876 - f1_score: 0.9876 - val_loss: 0.0313 - val_acc: 0.9911 - val_f1_score: 0.9906
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 - 31s - loss: 0.2416 - acc: 0.9264 - f1_score: 0.9201 - val_loss: 0.0558 - val_acc: 0.9817 - val_f1_score: 0.9826
#
# Epoch 2/10
# 60000/60000 - 32s - loss: 0.0842 - acc: 0.9748 - f1_score: 0.9755 - val_loss: 0.0353 - val_acc: 0.9878 - val_f1_score: 0.9880
#
# Epoch 3/10
# 60000/60000 - 31s - loss: 0.0601 - acc: 0.9818 - f1_score: 0.9819 - val_loss: 0.0335 - val_acc: 0.9887 - val_f1_score: 0.9891
#
# Epoch 4/10
# 60000/60000 - 31s - loss: 0.0496 - acc: 0.9853 - f1_score: 0.9854 - val_loss: 0.0302 - val_acc: 0.9901 - val_f1_score: 0.9892
#
# Epoch 5/10
# 60000/60000 - 31s - loss: 0.0432 - acc: 0.9862 - f1_score: 0.9862 - val_loss: 0.0272 - val_acc: 0.9911 - val_f1_score: 0.9911
#
# Epoch 6/10
# 60000/60000 - 31s - loss: 0.0386 - acc: 0.9883 - f1_score: 0.9883 - val_loss: 0.0274 - val_acc: 0.9915 - val_f1_score: 0.9919
#
# Epoch 7/10
# 60000/60000 - 31s - loss: 0.0305 - acc: 0.9896 - f1_score: 0.9897 - val_loss: 0.0298 - val_acc: 0.9904 - val_f1_score: 0.9906
#
# Epoch 8/10
# 60000/60000 - 34s - loss: 0.0298 - acc: 0.9904 - f1_score: 0.9903 - val_loss: 0.0301 - val_acc: 0.9904 - val_f1_score: 0.9907
#
# Epoch 9/10
# 60000/60000 - 31s - loss: 0.0271 - acc: 0.9912 - f1_score: 0.9913 - val_loss: 0.0258 - val_acc: 0.9923 - val_f1_score: 0.9925
#
# Epoch 10/10
# 60000/60000 - 31s - loss: 0.0224 - acc: 0.9927 - f1_score: 0.9928 - val_loss: 0.0260 - val_acc: 0.9925 - val_f1_score: 0.9926
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 - 31s - loss: 0.2235 - acc: 0.9319 - f1_score: 0.9281 - val_loss: 0.0547 - val_acc: 0.9820 - val_f1_score: 0.9817
#
# Epoch 2/10
# 60000/60000 - 32s - loss: 0.0825 - acc: 0.9757 - f1_score: 0.9761 - val_loss: 0.0474 - val_acc: 0.9839 - val_f1_score: 0.9842
#
# Epoch 3/10
# 60000/60000 - 32s - loss: 0.0637 - acc: 0.9818 - f1_score: 0.9819 - val_loss: 0.0426 - val_acc: 0.9861 - val_f1_score: 0.9857
#
# Epoch 4/10
# 60000/60000 - 32s - loss: 0.0532 - acc: 0.9847 - f1_score: 0.9849 - val_loss: 0.0414 - val_acc: 0.9865 - val_f1_score: 0.9868
#
# Epoch 5/10
# 60000/60000 - 32s - loss: 0.0494 - acc: 0.9857 - f1_score: 0.9857 - val_loss: 0.0327 - val_acc: 0.9904 - val_f1_score: 0.9904
#
# Epoch 6/10
# 60000/60000 - 32s - loss: 0.0447 - acc: 0.9872 - f1_score: 0.9872 - val_loss: 0.0307 - val_acc: 0.9902 - val_f1_score: 0.9905
#
# Epoch 7/10
# 60000/60000 - 32s - loss: 0.0444 - acc: 0.9870 - f1_score: 0.9872 - val_loss: 0.0291 - val_acc: 0.9911 - val_f1_score: 0.9914
#
# Epoch 8/10
# 60000/60000 - 32s - loss: 0.0458 - acc: 0.9872 - f1_score: 0.9871 - val_loss: 0.0366 - val_acc: 0.9880 - val_f1_score: 0.9875
#
# Epoch 9/10
# 60000/60000 - 32s - loss: 0.0479 - acc: 0.9863 - f1_score: 0.9863 - val_loss: 0.0385 - val_acc: 0.9873 - val_f1_score: 0.9880
#
# Epoch 10/10
# 60000/60000 - 32s - loss: 0.0480 - acc: 0.9867 - f1_score: 0.9865 - val_loss: 0.0300 - val_acc: 0.9905 - val_f1_score: 0.9899
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 - 31s - loss: 2.2856 - acc: 0.1374 - f1_score: 0.0000e+00 - val_loss: 2.2526 - val_acc: 0.2755 - val_f1_score: 0.0000e+00
#
# Epoch 2/10
# 60000/60000 - 31s - loss: 2.2307 - acc: 0.2427 - f1_score: 0.0000e+00 - val_loss: 2.1848 - val_acc: 0.4560 - val_f1_score: 0.0000e+00
#
# Epoch 3/10
# 60000/60000 - 31s - loss: 2.1599 - acc: 0.3406 - f1_score: 0.0000e+00 - val_loss: 2.0940 - val_acc: 0.5676 - val_f1_score: 0.0000e+00
#
# Epoch 4/10
# 60000/60000 - 31s - loss: 2.0634 - acc: 0.4265 - f1_score: 3.3057e-05 - val_loss: 1.9685 - val_acc: 0.6433 - val_f1_score: 0.0000e+00
#
# Epoch 5/10
# 60000/60000 - 32s - loss: 1.9382 - acc: 0.4977 - f1_score: 0.0042 - val_loss: 1.8075 - val_acc: 0.6930 - val_f1_score: 0.0049
#
# Epoch 6/10
# 60000/60000 - 31s - loss: 1.7850 - acc: 0.5462 - f1_score: 0.0322 - val_loss: 1.6195 - val_acc: 0.7298 - val_f1_score: 0.0613
#
# Epoch 7/10
# 60000/60000 - 32s - loss: 1.6165 - acc: 0.5874 - f1_score: 0.0895 - val_loss: 1.4199 - val_acc: 0.7565 - val_f1_score: 0.1210
#
# Epoch 8/10
# 60000/60000 - 32s - loss: 1.4548 - acc: 0.6210 - f1_score: 0.1859 - val_loss: 1.2307 - val_acc: 0.7836 - val_f1_score: 0.2493
#
# Epoch 9/10
# 60000/60000 - 31s - loss: 1.3101 - acc: 0.6443 - f1_score: 0.3171 - val_loss: 1.0681 - val_acc: 0.8026 - val_f1_score: 0.4326
#
# Epoch 10/10
# 60000/60000 - 31s - loss: 1.1879 - acc: 0.6653 - f1_score: 0.4319 - val_loss: 0.9360 - val_acc: 0.8171 - val_f1_score: 0.5662
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 - 31s - loss: 0.2368 - acc: 0.9269 - f1_score: 0.9217 - val_loss: 0.0541 - val_acc: 0.9825 - val_f1_score: 0.9833
#
# Epoch 2/10
# 60000/60000 - 31s - loss: 0.0854 - acc: 0.9750 - f1_score: 0.9750 - val_loss: 0.0356 - val_acc: 0.9875 - val_f1_score: 0.9879
#
# Epoch 3/10
# 60000/60000 - 31s - loss: 0.0610 - acc: 0.9817 - f1_score: 0.9818 - val_loss: 0.0343 - val_acc: 0.9881 - val_f1_score: 0.9884
#
# Epoch 4/10
# 60000/60000 - 31s - loss: 0.0509 - acc: 0.9845 - f1_score: 0.9846 - val_loss: 0.0311 - val_acc: 0.9888 - val_f1_score: 0.9894
#
# Epoch 5/10
# 60000/60000 - 31s - loss: 0.0447 - acc: 0.9857 - f1_score: 0.9860 - val_loss: 0.0293 - val_acc: 0.9910 - val_f1_score: 0.9914
#
# Epoch 6/10
# 60000/60000 - 31s - loss: 0.0369 - acc: 0.9885 - f1_score: 0.9884 - val_loss: 0.0268 - val_acc: 0.9908 - val_f1_score: 0.9910
#
# Epoch 7/10
# 60000/60000 - 31s - loss: 0.0331 - acc: 0.9894 - f1_score: 0.9895 - val_loss: 0.0302 - val_acc: 0.9908 - val_f1_score: 0.9910
#
# Epoch 8/10
# 60000/60000 - 31s - loss: 0.0309 - acc: 0.9901 - f1_score: 0.9902 - val_loss: 0.0347 - val_acc: 0.9898 - val_f1_score: 0.9895
#
# Epoch 9/10
# 60000/60000 - 31s - loss: 0.0262 - acc: 0.9914 - f1_score: 0.9914 - val_loss: 0.0300 - val_acc: 0.9908 - val_f1_score: 0.9909
#
# Epoch 10/10
# 60000/60000 - 31s - loss: 0.0242 - acc: 0.9920 - f1_score: 0.9921 - val_loss: 0.0324 - val_acc: 0.9909 - val_f1_score: 0.9909
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 - 31s - loss: 2.2926 - acc: 0.1293 - f1_score: 0.0000e+00 - val_loss: 2.2631 - val_acc: 0.3170 - val_f1_score: 0.0000e+00
#
# Epoch 2/10
# 60000/60000 - 32s - loss: 2.2460 - acc: 0.2520 - f1_score: 0.0000e+00 - val_loss: 2.2069 - val_acc: 0.6021 - val_f1_score: 0.0000e+00
#
# Epoch 3/10
# 60000/60000 - 32s - loss: 2.1870 - acc: 0.3705 - f1_score: 0.0000e+00 - val_loss: 2.1316 - val_acc: 0.6856 - val_f1_score: 0.0000e+00
#
# Epoch 4/10
# 60000/60000 - 32s - loss: 2.1056 - acc: 0.4548 - f1_score: 0.0000e+00 - val_loss: 2.0287 - val_acc: 0.7135 - val_f1_score: 0.0000e+00
#
# Epoch 5/10
# 60000/60000 - 32s - loss: 1.9948 - acc: 0.5125 - f1_score: 0.0000e+00 - val_loss: 1.8889 - val_acc: 0.7328 - val_f1_score: 0.0000e+00
#
# Epoch 6/10
# 60000/60000 - 32s - loss: 1.8518 - acc: 0.5546 - f1_score: 8.3734e-04 - val_loss: 1.7075 - val_acc: 0.7505 - val_f1_score: 0.0000e+00
#
# Epoch 7/10
# 60000/60000 - 31s - loss: 1.6810 - acc: 0.5858 - f1_score: 0.0238 - val_loss: 1.4992 - val_acc: 0.7612 - val_f1_score: 0.0252
#
# Epoch 8/10
# 60000/60000 - 31s - loss: 1.5026 - acc: 0.6117 - f1_score: 0.1251 - val_loss: 1.2925 - val_acc: 0.7796 - val_f1_score: 0.1932
#
# Epoch 9/10
# 60000/60000 - 31s - loss: 1.3442 - acc: 0.6343 - f1_score: 0.2827 - val_loss: 1.1141 - val_acc: 0.7946 - val_f1_score: 0.4207
#
# Epoch 10/10
# 60000/60000 - 31s - loss: 1.2078 - acc: 0.6609 - f1_score: 0.4223 - val_loss: 0.9711 - val_acc: 0.8093 - val_f1_score: 0.5446
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 - 31s - loss: 2.2744 - acc: 0.1616 - f1_score: 0.0000e+00 - val_loss: 2.2160 - val_acc: 0.3663 - val_f1_score: 0.0000e+00
#
# Epoch 2/10
# 60000/60000 - 31s - loss: 2.1862 - acc: 0.2933 - f1_score: 0.0000e+00 - val_loss: 2.1079 - val_acc: 0.5459 - val_f1_score: 0.0000e+00
#
# Epoch 3/10
# 60000/60000 - 31s - loss: 2.0759 - acc: 0.4037 - f1_score: 0.0000e+00 - val_loss: 1.9677 - val_acc: 0.6581 - val_f1_score: 0.0000e+00
#
# Epoch 4/10
# 60000/60000 - 31s - loss: 1.9373 - acc: 0.4820 - f1_score: 0.0019 - val_loss: 1.7939 - val_acc: 0.7214 - val_f1_score: 0.0000e+00
#
# Epoch 5/10
# 60000/60000 - 31s - loss: 1.7739 - acc: 0.5412 - f1_score: 0.0200 - val_loss: 1.5948 - val_acc: 0.7602 - val_f1_score: 0.0347
#
# Epoch 6/10
# 60000/60000 - 31s - loss: 1.5980 - acc: 0.5862 - f1_score: 0.0798 - val_loss: 1.3911 - val_acc: 0.7837 - val_f1_score: 0.1090
#
# Epoch 7/10
# 60000/60000 - 31s - loss: 1.4367 - acc: 0.6182 - f1_score: 0.1966 - val_loss: 1.2046 - val_acc: 0.7987 - val_f1_score: 0.2985
#
# Epoch 8/10
# 60000/60000 - 31s - loss: 1.2918 - acc: 0.6460 - f1_score: 0.3363 - val_loss: 1.0463 - val_acc: 0.8136 - val_f1_score: 0.4608
#
# Epoch 9/10
# 60000/60000 - 31s - loss: 1.1750 - acc: 0.6673 - f1_score: 0.4483 - val_loss: 0.9204 - val_acc: 0.8226 - val_f1_score: 0.5799
#
# Epoch 10/10
# 60000/60000 - 31s - loss: 1.0821 - acc: 0.6851 - f1_score: 0.5299 - val_loss: 0.8229 - val_acc: 0.8309 - val_f1_score: 0.6604
#
# 100%|██████████| 10/10 [53:09<00:00, 319.00s/trial, best loss: 0.0]

# %%
best
# Out:
# {'lr': 3.989865204889641e-05, 'optimizer_str': 2}

# %%
hp.choice('optimizer_str', ['RMSprop', 'Adam', 'Adadelta'])['optimizer_str']
